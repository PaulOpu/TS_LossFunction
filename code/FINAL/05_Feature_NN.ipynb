# %% [markdown]
# # NN to Predict Feature Scores

# %% [markdown]
# <div class="alert alert-block alert-warning">
# This notebook deals contains the following aspects:
# <li>Neural Network architecture to predict the linguistical features itself</li>
# <li>Explore the mean of the loss for each feature</li>
# </div>

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import re
import os
import math
import codecs
from collections import Counter
from nltk import word_tokenize,sent_tokenize
from gensim.models import Word2Vec
import spacy
import matplotlib.pyplot as plt
from gensim.models import KeyedVectors
from tqdm import tqdm
import ast
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score,mean_squared_error
from feature_extraction import TextFeatureCreator

def roundup(x):
    return int(math.ceil(x / 10.0)) * 10

# %%
#lemmatizer
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ### Helper Functions

# %%
def yield_file_text(df):
    #generator that gives a text each time next(<generator>) is called
    for ind,row in df.iterrows():
        if row["path"] != 'data/LSATtexts.txt':
            yield get_file_text(row)

# %%
def get_file_text(row):
    #load the text from the file 
    #(used by yield_file_text)
    path = row["path"]#.split("/")[-1]
    #path= clean_newsela_path+path

    with codecs.open(path, "r",encoding='utf-8', errors='ignore') as f:
        text = f.read()
        #if tokenize:
        #    text = [[word.text.lower() for word in nlp(sent)] for sent in text.split(".")]
        return text

# %% [markdown]
# ### Exchange lemmatized text by word2vec vectors

# %%
def text_to_vector(word2vec_model,text):
    vectorized_text = [
            [word2vec_model.wv[word] 
             for word in sent if word in lem_word2vec_model.wv.vocab] 
         for sent in text]
    
    #print(vectorized_text)
    vectorized_text = [sent for sent in vectorized_text if sent]
    return vectorized_text

# %%
df = pd.read_csv("/data/ts_cost_function/dataset_features_and_text.csv",sep="|")
df["text"] = df.apply(lambda x: ast.literal_eval(x["text"]),axis=1)
lem_word2vec_model = Word2Vec.load("/data/ts_cost_function/word2vec_lem.model")
vectorized_texts = df.apply(lambda x: text_to_vector(lem_word2vec_model,x["text"]),axis=1)
df["embed"] = vectorized_texts
df.head(1)
# Out:
#                                                 path  feature_sums  \
# 0  /data/ts_cost_function/clean_newsela/kea-extin...      7.687178
#
#    regression_score  Mean word length  Mean sentence length  \
# 0          0.326461           0.90909              0.306252
#
#    Basic english ratio  Syllables per sentence  Type token ratio    #nouns  \
# 0             1.298557                0.263046          0.845914  0.365935
#
#      #verbs                        ...                          Coordination  \
# 0  0.465726                        ...                              0.202795
#
#    Apposition  Passive verbs  Parataxis  Auxiliary Verbs  Negation  \
# 0         0.0       0.256415        0.0         0.366106  0.201348
#
#    Prepositional Phrases  Modifiers  \
# 0               0.203278   0.256116
#
#                                                 text  \
# 0  [[one, of, the, big, threat, to, the, kea, be,...
#
#                                                embed
# 0  [[[2.2008598, 2.7345686, 1.5816159, -0.3842493...
#
# [1 rows x 25 columns]

# %% [markdown]
# ## TF Estimator Input_Fn

# %% [markdown]
# ### Add padding at text and sentence level

# %%
def embed_padding(embed,max_sent,max_word,embed_size):
    result = np.zeros((max_sent,max_word,embed_size))
    for sent_ind,sent in enumerate(embed[:max_sent]):
        for word_ind,word in enumerate(sent[:max_word]):
            result[sent_ind,word_ind] = word
    return result

# %%
df["embed_pad"] = df.apply(
        lambda x: embed_padding(
            x["embed"],
            100,
            100,
            50),
        axis=1)

# %% [markdown]
# ### Text Generators

# %%
feature_columns = df.columns[3:-3]
def word_embed_generator(df):
    #Yields each text and label of the training set
    for ind,row in df.iterrows():
        yield (row["embed_pad"],row[feature_columns])

# %%
def prediction_generator(df):
    #Yields only the text for prediction 
    for ind,row in df.iterrows():
        yield (row["embed_pad"],[0]*20)

# %% [markdown]
# ### Define Input Functon

# %%
def train_word_emb_fn(df,batch_size,model):
    #Loads the training data for the tf estimator
    max_sent = model.params["text_size"]
    max_word = model.params["sent_size"]
    embed_size = model.params["word_size"]
    #dataset = tf.data.Dataset.from_tensor_slices((dict(df["embed_pad"]), df["regression_score"]))

    dataset = tf.data.Dataset.from_generator(lambda: 
                                             word_embed_generator(df), 
                                             (tf.float64, tf.float64), 
                                             (tf.TensorShape([max_sent,max_word,embed_size]),
                                             tf.TensorShape([20])))

    # Shuffle, repeat, and batch the examples.
    dataset = dataset.shuffle(1000).repeat().batch(batch_size)
    #shuffle(1000)
    
    # Return the dataset.
    return dataset

# %%
def eval_word_emb_fn(df,batch_size,model):
    #Loads the evaluation data for the tf estimator
    max_sent = model.params["text_size"]
    max_word = model.params["sent_size"]
    embed_size = model.params["word_size"]

    dataset = tf.data.Dataset.from_generator(lambda: 
                                             prediction_generator(df), 
                                             (tf.float64, tf.float64), 
                                             (tf.TensorShape([max_sent,max_word,embed_size]),
                                             tf.TensorShape([20])))

    dataset = dataset.batch(batch_size)

    # Return the read end of the pipeline.
    return dataset.make_one_shot_iterator().get_next()

# %% [markdown]
# ## Define Training and Test Set

# %% [markdown]
# ### Load Splitting

# %%
index_df = pd.read_csv("/data/ts_cost_function/train_test_indices.csv",sep=";")
train_df = df.iloc[index_df.loc[index_df["dataset"] == "train"]["index"].values]
test_df = df.iloc[index_df.loc[index_df["dataset"] == "test"]["index"].values]
train_df.head(1)
# Out:
#                                                     path  feature_sums  \
# 13620  /data/ts_cost_function/clean_newsela/planet-ni...      17.80152
#
#        regression_score  Mean word length  Mean sentence length  \
# 13620           0.67148          0.919342              0.784718
#
#        Basic english ratio  Syllables per sentence  Type token ratio  \
# 13620             1.041918                0.735701          0.819199
#
#          #nouns   #verbs                        ...                          \
# 13620  0.842614  0.80318                        ...
#
#        Apposition  Passive verbs  Parataxis  Auxiliary Verbs  Negation  \
# 13620    0.788785       0.610511   2.874718         0.591498  1.198502
#
#        Prepositional Phrases  Modifiers  \
# 13620               0.643021    0.68447
#
#                                                     text  \
# 13620  [[an, answer, for, planet, ', strange, alignme...
#
#                                                    embed  \
# 13620  [[[6.1390705, 2.7747629, -2.6474686, -0.170415...
#
#                                                embed_pad
# 13620  [[[6.139070510864258, 2.7747628688812256, -2.6...
#
# [1 rows x 26 columns]

# %% [markdown]
# ## NN Architecture

# %% [markdown]
# ### Embedding + Sentence RNN + Text RNN => Features

# %%
model_path = "/data/ts_cost_function/model_emb_rnn_rnn_features"

hyperparameter = {
    "text_size" : 100,
    "sent_size" : 100,
    "word_size" : 50,
    "learning_rate": 0.0001,#0.0001
    "sent_hidden_state_size": 64,
    "text_hidden_state_size": 64
}

# %% [markdown]
# ### Model Function

# %%
def model_emb_rnn_rnn_feature_fn(features, labels, mode, params):
    #Model Function of the architecture
    
    batch_size = global_batch_size
    text_size = params["text_size"]
    sent_size = params["sent_size"]
    word_size = params["word_size"]
    learn_rate = params["learning_rate"]
    sent_hidden_state_size = params["sent_hidden_state_size"]
    text_hidden_state_size = params["text_hidden_state_size"]
    #n_steps_summary = params["every_n_steps_summarize"]
    #model_path = params["model_path"]
    
    

    
    #Mask the length of each sentence 
    word_mask = tf.reduce_max(
        tf.count_nonzero(
            tf.reshape(
                features,
                [batch_size*text_size,sent_size,word_size]),
            1),
        1)
    #Mask the length of each text
    sent_mask = tf.count_nonzero(
        tf.reduce_max(
            tf.count_nonzero(
                features,
                2),
            2),
        1)
    
    #Concat all sentences of all texts of a batch together to use word_mask
    concat_sents = tf.reshape(features,[batch_size*text_size,sent_size,word_size])
    
    
    #LSTM for each word in a sentence
    with tf.variable_scope('word_cell'):
        word_cell = tf.contrib.rnn.BasicLSTMCell(num_units=sent_hidden_state_size, state_is_tuple=True)
        word_outputs, word_last_states = tf.nn.dynamic_rnn(
            cell=word_cell,
            dtype=tf.float64,
            sequence_length=word_mask,
            #initial_state=init_state,
            inputs=concat_sents)
        
        reshaped_word_last_states = tf.reshape(word_last_states.c,[batch_size,text_size,sent_hidden_state_size])
    
    #LSTM for each sentence in a text
    with tf.variable_scope('sent_cell'):
        sent_cell = tf.contrib.rnn.BasicLSTMCell(num_units=text_hidden_state_size, state_is_tuple=False)
        sent_outputs, sent_last_states = tf.nn.dynamic_rnn(
            cell=sent_cell,
            dtype=tf.float64,
            sequence_length=sent_mask,
            inputs=reshaped_word_last_states)
        
    #summary
    for name,cell in [("word",word_cell),("sent",sent_cell)]:
        one_kernel, one_bias = cell.variables
        # I think TensorBoard handles summaries with the same name fine.
        tf.summary.histogram(name+"_kernel", one_kernel)
        tf.summary.histogram(name+"_bias", one_bias)
    
    #shrink last hidden state of each text
    dense_layer = tf.layers.dense(inputs=sent_last_states, units=64, activation=None)
    
    pred_value = tf.layers.dense(inputs=dense_layer, units=20, activation=None)
    
    predictions = {
        # Generate predictions (for PREDICT and EVAL mode)
        "logits": pred_value,
        "word_outputs":word_outputs,
        "sent_outputs":sent_outputs,
        "word_mask":word_mask,
        "sent_mask":sent_mask
        
    }
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions=predictions)
    
    #MSE for loss
    reshaped_labels = tf.reshape(labels,[batch_size,20])
    print(reshaped_labels)
    cost = tf.losses.mean_squared_error(reshaped_labels,pred_value)
    mse = tf.metrics.mean_squared_error(reshaped_labels,pred_value)
    
    tf.summary.scalar('mse', mse[1])
    
    if mode == tf.estimator.ModeKeys.TRAIN:
        #Adam Optimizer
        optimizer = tf.train.AdamOptimizer(
            learning_rate=learn_rate)
        train_op = optimizer.minimize(
            loss=cost,
            global_step=tf.train.get_global_step())
        
        return tf.estimator.EstimatorSpec(
            mode=mode, 
            loss=cost,
            train_op=train_op)
    
    print(cost)
    eval_metric_ops = {
      "MSE": mse}
    return tf.estimator.EstimatorSpec(
      mode=mode, loss=cost, eval_metric_ops=eval_metric_ops)

# %% [markdown]
# ### Create Estimator

# %%
#Change the checkpoint config
checkpointing_config = tf.estimator.RunConfig(
    #save_checkpoints_secs = 60*10,  # Save checkpoints every 10 minutes.
    keep_checkpoint_max = 5,       # Retain the 10 most recent checkpoints.
    save_summary_steps=10
)

#Define Estimator
model_emb_rnn_rnn = tf.estimator.Estimator(
    model_fn=model_emb_rnn_rnn_feature_fn, 
    model_dir=model_path,
    params=hyperparameter,
    config=checkpointing_config)

tf.logging.set_verbosity(tf.logging.INFO)
# Out:
# INFO:tensorflow:Using config: {'_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_tf_random_seed': None, '_num_worker_replicas': 1, '_is_chief': True, '_num_ps_replicas': 0, '_model_dir': '/data/ts_cost_function/model_emb_rnn_rnn_features', '_save_summary_steps': 10, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f5ade72e550>, '_master': '', '_evaluation_master': '', '_keep_checkpoint_every_n_hours': 10000, '_keep_checkpoint_max': 5, '_session_config': None, '_global_id_in_cluster': 0, '_log_step_count_steps': 100, '_train_distribute': None, '_task_id': 0, '_task_type': 'worker', '_service': None}

# %% [markdown]
# ### Train Model

# %%
#Reduce the batch size, because of memory errors
train_batch_size = 2
global_batch_size = train_batch_size
train_steps = 17000

training = model_emb_rnn_rnn.train(
        input_fn=lambda:train_word_emb_fn(
            train_df,
            train_batch_size,
            model_emb_rnn_rnn),
        #hooks=[logging_hook],
        max_steps=train_steps)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7f5ade718208>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# Tensor("Reshape_2:0", shape=(2, 20), dtype=float64)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /data/ts_cost_function/model_emb_rnn_rnn_features/model.ckpt.
# INFO:tensorflow:step = 0, loss = 0.5381682
# INFO:tensorflow:global_step/sec: 7.80148
# INFO:tensorflow:step = 100, loss = 0.028795352 (12.820 sec)
# INFO:tensorflow:global_step/sec: 8.14086
# INFO:tensorflow:step = 200, loss = 0.0648407 (12.283 sec)
# INFO:tensorflow:global_step/sec: 8.32149
# INFO:tensorflow:step = 300, loss = 0.10165029 (12.018 sec)
# INFO:tensorflow:global_step/sec: 8.37768
# INFO:tensorflow:step = 400, loss = 0.101994 (11.937 sec)
# INFO:tensorflow:global_step/sec: 8.51561
# INFO:tensorflow:step = 500, loss = 0.23929639 (11.743 sec)
# INFO:tensorflow:global_step/sec: 8.46228
# INFO:tensorflow:step = 600, loss = 0.09945663 (11.817 sec)
# INFO:tensorflow:global_step/sec: 8.47432
# INFO:tensorflow:step = 700, loss = 0.05745653 (11.802 sec)
# INFO:tensorflow:global_step/sec: 8.59619
# INFO:tensorflow:step = 800, loss = 0.057446122 (11.631 sec)
# INFO:tensorflow:global_step/sec: 8.28595
# INFO:tensorflow:step = 1800, loss = 0.03844129 (12.069 sec)
# INFO:tensorflow:global_step/sec: 8.63464
# INFO:tensorflow:step = 1900, loss = 0.036490936 (11.581 sec)
# INFO:tensorflow:global_step/sec: 8.55255
# INFO:tensorflow:step = 2000, loss = 0.05045983 (11.693 sec)
# INFO:tensorflow:global_step/sec: 8.527
# INFO:tensorflow:step = 2100, loss = 0.9770544 (11.727 sec)
# INFO:tensorflow:global_step/sec: 8.6697
# INFO:tensorflow:step = 2200, loss = 0.05040812 (11.535 sec)
# INFO:tensorflow:global_step/sec: 8.54567
# INFO:tensorflow:step = 2300, loss = 0.07253592 (11.704 sec)
# INFO:tensorflow:global_step/sec: 8.56215
# INFO:tensorflow:step = 2400, loss = 0.044253107 (11.678 sec)
# INFO:tensorflow:global_step/sec: 8.50424
# INFO:tensorflow:step = 2500, loss = 0.03258897 (11.759 sec)
# INFO:tensorflow:global_step/sec: 8.23669
# INFO:tensorflow:step = 2600, loss = 0.023596322 (12.140 sec)
# INFO:tensorflow:global_step/sec: 8.43865
# INFO:tensorflow:step = 2700, loss = 0.06955717 (11.852 sec)
# INFO:tensorflow:global_step/sec: 8.2911
# INFO:tensorflow:step = 2800, loss = 0.049342893 (12.060 sec)
# INFO:tensorflow:global_step/sec: 8.54708
# INFO:tensorflow:step = 2900, loss = 0.060070343 (11.699 sec)
# INFO:tensorflow:global_step/sec: 8.55942
# INFO:tensorflow:step = 3000, loss = 0.06368112 (11.684 sec)
# INFO:tensorflow:global_step/sec: 8.45254
# INFO:tensorflow:step = 3100, loss = 0.3059943 (11.831 sec)
# INFO:tensorflow:global_step/sec: 8.22074
# INFO:tensorflow:step = 3200, loss = 0.08859487 (12.166 sec)
# INFO:tensorflow:global_step/sec: 8.55534
# INFO:tensorflow:step = 3300, loss = 0.042086482 (11.687 sec)
# INFO:tensorflow:global_step/sec: 8.44324
# INFO:tensorflow:step = 3400, loss = 0.054643463 (11.844 sec)
# INFO:tensorflow:global_step/sec: 8.38738
# INFO:tensorflow:step = 3500, loss = 0.123170115 (11.923 sec)
# INFO:tensorflow:global_step/sec: 8.57412
# INFO:tensorflow:step = 3600, loss = 0.03384587 (11.663 sec)
# INFO:tensorflow:global_step/sec: 8.35337
# INFO:tensorflow:step = 3700, loss = 0.023211252 (11.971 sec)
# INFO:tensorflow:global_step/sec: 8.28571
# INFO:tensorflow:step = 3800, loss = 0.0381735 (12.069 sec)
# INFO:tensorflow:global_step/sec: 8.57822
# INFO:tensorflow:step = 3900, loss = 0.054862738 (11.657 sec)
# INFO:tensorflow:global_step/sec: 8.62165
# INFO:tensorflow:step = 4000, loss = 0.06628011 (11.600 sec)
# INFO:tensorflow:global_step/sec: 8.6144
# INFO:tensorflow:step = 4100, loss = 0.042338382 (11.607 sec)
# INFO:tensorflow:global_step/sec: 8.43475
# INFO:tensorflow:step = 4200, loss = 0.28501862 (11.855 sec)
# INFO:tensorflow:global_step/sec: 8.59329
# INFO:tensorflow:step = 4300, loss = 0.09034022 (11.637 sec)
# INFO:tensorflow:global_step/sec: 8.3559
# INFO:tensorflow:step = 4400, loss = 0.03800712 (11.968 sec)
# INFO:tensorflow:global_step/sec: 8.34066
# INFO:tensorflow:step = 4500, loss = 0.07774928 (11.989 sec)
# INFO:tensorflow:global_step/sec: 8.44429
# INFO:tensorflow:step = 4600, loss = 0.030070866 (11.843 sec)
# INFO:tensorflow:global_step/sec: 8.58123
# INFO:tensorflow:step = 4700, loss = 0.06379174 (11.653 sec)
# INFO:tensorflow:global_step/sec: 8.63115
# INFO:tensorflow:step = 4800, loss = 0.012769498 (11.585 sec)
# INFO:tensorflow:global_step/sec: 8.6087
# INFO:tensorflow:step = 4900, loss = 0.053620186 (11.618 sec)
# INFO:tensorflow:global_step/sec: 8.52794
# INFO:tensorflow:step = 5000, loss = 0.012756983 (11.725 sec)
# INFO:tensorflow:Saving checkpoints for 5069 into /data/ts_cost_function/model_emb_rnn_rnn_features/model.ckpt.
# INFO:tensorflow:global_step/sec: 8.22925
# INFO:tensorflow:step = 5100, loss = 0.15184799 (12.151 sec)
# INFO:tensorflow:global_step/sec: 8.45817
# INFO:tensorflow:step = 5200, loss = 0.047203388 (11.823 sec)
# INFO:tensorflow:global_step/sec: 8.18981
# INFO:tensorflow:step = 5300, loss = 0.08764651 (12.210 sec)
# INFO:tensorflow:global_step/sec: 8.63835
# INFO:tensorflow:step = 5400, loss = 0.06719702 (11.576 sec)
# INFO:tensorflow:global_step/sec: 8.41148
# INFO:tensorflow:step = 5500, loss = 0.03739825 (11.888 sec)
# INFO:tensorflow:global_step/sec: 8.69936
# INFO:tensorflow:step = 5600, loss = 0.047509577 (11.495 sec)
# INFO:tensorflow:global_step/sec: 8.47905
# INFO:tensorflow:step = 5700, loss = 0.02772445 (11.794 sec)
# INFO:tensorflow:global_step/sec: 8.38726
# INFO:tensorflow:step = 5800, loss = 0.024395922 (11.924 sec)
# INFO:tensorflow:global_step/sec: 8.50762
# INFO:tensorflow:step = 5900, loss = 0.0502037 (11.753 sec)
# INFO:tensorflow:global_step/sec: 8.58586
# INFO:tensorflow:step = 6000, loss = 0.09688354 (11.647 sec)
# INFO:tensorflow:global_step/sec: 8.38342
# INFO:tensorflow:step = 6100, loss = 0.02066324 (11.930 sec)
# INFO:tensorflow:global_step/sec: 8.19661
# INFO:tensorflow:step = 6200, loss = 0.040626835 (12.198 sec)
# INFO:tensorflow:global_step/sec: 8.51374
# INFO:tensorflow:step = 6300, loss = 0.015899152 (11.746 sec)
# INFO:tensorflow:global_step/sec: 8.37102
# INFO:tensorflow:step = 6400, loss = 0.10522473 (11.946 sec)
# INFO:tensorflow:global_step/sec: 8.77199
# INFO:tensorflow:step = 6500, loss = 0.022949265 (11.400 sec)
# INFO:tensorflow:global_step/sec: 8.54642
# INFO:tensorflow:step = 6600, loss = 0.026845876 (11.703 sec)
# INFO:tensorflow:global_step/sec: 8.56468
# INFO:tensorflow:step = 6700, loss = 0.054626863 (11.674 sec)
# INFO:tensorflow:global_step/sec: 8.45181
# INFO:tensorflow:step = 6800, loss = 0.034253486 (11.832 sec)
# INFO:tensorflow:global_step/sec: 8.32436
# INFO:tensorflow:step = 6900, loss = 0.053187747 (12.013 sec)
# INFO:tensorflow:global_step/sec: 8.50274
# INFO:tensorflow:step = 7000, loss = 0.040801745 (11.761 sec)
# INFO:tensorflow:global_step/sec: 8.44524
# INFO:tensorflow:step = 7100, loss = 0.16126837 (11.841 sec)
# INFO:tensorflow:global_step/sec: 8.6342
# INFO:tensorflow:step = 7200, loss = 0.013230701 (11.582 sec)
# INFO:tensorflow:global_step/sec: 8.59543
# INFO:tensorflow:step = 7300, loss = 0.093455516 (11.634 sec)
# INFO:tensorflow:global_step/sec: 8.68441
# INFO:tensorflow:step = 7400, loss = 0.021544436 (11.515 sec)
# INFO:tensorflow:global_step/sec: 8.45443
# INFO:tensorflow:step = 7500, loss = 0.05418352 (11.829 sec)
# INFO:tensorflow:global_step/sec: 8.58347
# INFO:tensorflow:step = 7600, loss = 0.017882502 (11.649 sec)
# INFO:tensorflow:global_step/sec: 8.46816
# INFO:tensorflow:step = 7700, loss = 0.061537188 (11.808 sec)
# INFO:tensorflow:global_step/sec: 8.11268
# INFO:tensorflow:step = 7800, loss = 0.041802716 (12.327 sec)
# INFO:tensorflow:global_step/sec: 8.54176
# INFO:tensorflow:step = 7900, loss = 0.049005207 (11.707 sec)
# INFO:tensorflow:global_step/sec: 8.51102
# INFO:tensorflow:step = 8000, loss = 0.025418466 (11.750 sec)
# INFO:tensorflow:global_step/sec: 8.43757
# INFO:tensorflow:step = 8100, loss = 0.040056895 (11.851 sec)
# INFO:tensorflow:global_step/sec: 9.49975
# INFO:tensorflow:step = 8200, loss = 0.07483738 (10.527 sec)
# INFO:tensorflow:global_step/sec: 9.29505
# INFO:tensorflow:step = 8300, loss = 0.06337586 (10.758 sec)
# INFO:tensorflow:global_step/sec: 9.38181
# INFO:tensorflow:step = 8400, loss = 0.018125512 (10.660 sec)
# INFO:tensorflow:global_step/sec: 9.28008
# INFO:tensorflow:step = 8500, loss = 0.32003635 (10.775 sec)
# INFO:tensorflow:global_step/sec: 6.23278
# INFO:tensorflow:step = 8600, loss = 0.02509579 (16.044 sec)
# INFO:tensorflow:global_step/sec: 8.48095
# INFO:tensorflow:step = 8700, loss = 0.034077115 (11.790 sec)
# INFO:tensorflow:global_step/sec: 8.46206
# INFO:tensorflow:step = 8800, loss = 0.044310767 (11.818 sec)
# INFO:tensorflow:global_step/sec: 8.78443
# INFO:tensorflow:step = 8900, loss = 0.04142871 (11.384 sec)
# INFO:tensorflow:global_step/sec: 8.5259
# INFO:tensorflow:step = 9000, loss = 0.029353602 (11.729 sec)
# INFO:tensorflow:global_step/sec: 8.60345
# INFO:tensorflow:step = 9100, loss = 0.018613918 (11.624 sec)
# INFO:tensorflow:global_step/sec: 8.50855
# INFO:tensorflow:step = 9200, loss = 0.043662645 (11.754 sec)
# INFO:tensorflow:global_step/sec: 8.67136
# INFO:tensorflow:step = 9300, loss = 0.030608013 (11.531 sec)
# INFO:tensorflow:global_step/sec: 8.39847
# INFO:tensorflow:step = 9400, loss = 0.2122486 (11.907 sec)
# INFO:tensorflow:global_step/sec: 8.55225
# INFO:tensorflow:step = 9500, loss = 0.08726814 (11.693 sec)
# INFO:tensorflow:global_step/sec: 8.46033
# INFO:tensorflow:step = 9600, loss = 0.19974652 (11.819 sec)
# INFO:tensorflow:global_step/sec: 8.63383
# INFO:tensorflow:step = 9700, loss = 0.041047852 (11.583 sec)
# INFO:tensorflow:global_step/sec: 8.58372
# INFO:tensorflow:step = 9800, loss = 0.046043415 (11.650 sec)
# INFO:tensorflow:global_step/sec: 8.47241
# INFO:tensorflow:step = 9900, loss = 0.018781425 (11.803 sec)
# INFO:tensorflow:global_step/sec: 8.57768
# INFO:tensorflow:step = 10000, loss = 0.032978456 (11.658 sec)
# INFO:tensorflow:global_step/sec: 8.44454
# INFO:tensorflow:step = 10100, loss = 0.026328241 (11.844 sec)
# INFO:tensorflow:Saving checkpoints for 10168 into /data/ts_cost_function/model_emb_rnn_rnn_features/model.ckpt.
# INFO:tensorflow:global_step/sec: 8.30179
# INFO:tensorflow:step = 10200, loss = 0.09815652 (12.043 sec)
# INFO:tensorflow:global_step/sec: 8.43912
# INFO:tensorflow:step = 10300, loss = 0.059011508 (11.850 sec)
# INFO:tensorflow:global_step/sec: 8.30518
# INFO:tensorflow:step = 10400, loss = 0.017464692 (12.041 sec)
# INFO:tensorflow:global_step/sec: 8.61679
# INFO:tensorflow:step = 10500, loss = 0.03906505 (11.605 sec)
# INFO:tensorflow:global_step/sec: 8.38522
# INFO:tensorflow:step = 10600, loss = 0.01798581 (11.926 sec)
# INFO:tensorflow:global_step/sec: 8.26069
# INFO:tensorflow:step = 10700, loss = 0.023897493 (12.106 sec)
# INFO:tensorflow:global_step/sec: 8.44111
# INFO:tensorflow:step = 10800, loss = 0.25110626 (11.847 sec)
# INFO:tensorflow:global_step/sec: 8.65791
# INFO:tensorflow:step = 10900, loss = 0.026635105 (11.550 sec)
# INFO:tensorflow:global_step/sec: 8.40351
# INFO:tensorflow:step = 11000, loss = 0.023779195 (11.902 sec)
# INFO:tensorflow:global_step/sec: 8.57437
# INFO:tensorflow:step = 11100, loss = 0.01075028 (11.661 sec)
# INFO:tensorflow:global_step/sec: 8.42908
# INFO:tensorflow:step = 11200, loss = 0.022120133 (11.864 sec)
# INFO:tensorflow:global_step/sec: 8.44567
# INFO:tensorflow:step = 11300, loss = 0.04627262 (11.840 sec)
# INFO:tensorflow:global_step/sec: 8.56007
# INFO:tensorflow:step = 11400, loss = 0.09707079 (11.682 sec)
# INFO:tensorflow:global_step/sec: 8.40374
# INFO:tensorflow:step = 11500, loss = 0.014311816 (11.900 sec)
# INFO:tensorflow:global_step/sec: 8.40637
# INFO:tensorflow:step = 11600, loss = 0.018095128 (11.896 sec)
# INFO:tensorflow:global_step/sec: 8.21694
# INFO:tensorflow:step = 11700, loss = 0.031253975 (12.170 sec)
# INFO:tensorflow:global_step/sec: 8.38899
# INFO:tensorflow:step = 11800, loss = 0.0480985 (11.920 sec)
# INFO:tensorflow:global_step/sec: 8.59148
# INFO:tensorflow:step = 11900, loss = 0.01582936 (11.642 sec)
# INFO:tensorflow:global_step/sec: 8.5604
# INFO:tensorflow:step = 12000, loss = 0.049824078 (11.682 sec)
# INFO:tensorflow:global_step/sec: 8.33053
# INFO:tensorflow:step = 12100, loss = 0.07610604 (12.002 sec)
# INFO:tensorflow:global_step/sec: 8.26106
# INFO:tensorflow:step = 12200, loss = 0.029238602 (12.104 sec)
# INFO:tensorflow:global_step/sec: 8.56075
# INFO:tensorflow:step = 12300, loss = 0.35063282 (11.681 sec)
# INFO:tensorflow:global_step/sec: 8.55032
# INFO:tensorflow:step = 12400, loss = 0.01166481 (11.696 sec)
# INFO:tensorflow:global_step/sec: 8.56151
# INFO:tensorflow:step = 12500, loss = 0.03283462 (11.680 sec)
# INFO:tensorflow:global_step/sec: 8.59951
# INFO:tensorflow:step = 12600, loss = 0.024650259 (11.629 sec)
# INFO:tensorflow:global_step/sec: 8.63989
# INFO:tensorflow:step = 12700, loss = 0.01739539 (11.577 sec)
# INFO:tensorflow:global_step/sec: 8.4723
# INFO:tensorflow:step = 12800, loss = 0.082629524 (11.800 sec)
# INFO:tensorflow:global_step/sec: 8.44552
# INFO:tensorflow:step = 12900, loss = 0.051617473 (11.841 sec)
# INFO:tensorflow:global_step/sec: 8.41508
# INFO:tensorflow:step = 13000, loss = 0.116566055 (11.883 sec)
# INFO:tensorflow:global_step/sec: 8.51407
# INFO:tensorflow:step = 13100, loss = 0.052410223 (11.745 sec)
# INFO:tensorflow:global_step/sec: 8.52979
# INFO:tensorflow:step = 13200, loss = 0.025044173 (11.723 sec)
# INFO:tensorflow:global_step/sec: 8.5371
# INFO:tensorflow:step = 13300, loss = 0.052643664 (11.713 sec)
# INFO:tensorflow:global_step/sec: 8.73288
# INFO:tensorflow:step = 13400, loss = 0.030222058 (11.452 sec)
# INFO:tensorflow:global_step/sec: 8.5219
# INFO:tensorflow:step = 13500, loss = 0.024369802 (11.734 sec)
# INFO:tensorflow:global_step/sec: 8.46972
# INFO:tensorflow:step = 13600, loss = 0.021012032 (11.808 sec)
# INFO:tensorflow:global_step/sec: 8.71822
# INFO:tensorflow:step = 13700, loss = 0.05536154 (11.469 sec)
# INFO:tensorflow:global_step/sec: 8.20169
# INFO:tensorflow:step = 13800, loss = 0.075978436 (12.192 sec)
# INFO:tensorflow:global_step/sec: 8.44339
# INFO:tensorflow:step = 13900, loss = 0.05027349 (11.844 sec)
# INFO:tensorflow:global_step/sec: 8.55003
# INFO:tensorflow:step = 14000, loss = 0.036155466 (11.699 sec)
# INFO:tensorflow:global_step/sec: 8.38945
# INFO:tensorflow:step = 14100, loss = 0.03240598 (11.917 sec)
# INFO:tensorflow:global_step/sec: 8.45538
# INFO:tensorflow:step = 14200, loss = 0.011391635 (11.826 sec)
# INFO:tensorflow:global_step/sec: 8.64567
# INFO:tensorflow:step = 14300, loss = 0.020029197 (11.567 sec)
# INFO:tensorflow:global_step/sec: 8.50385
# INFO:tensorflow:step = 14400, loss = 0.077381745 (11.759 sec)
# INFO:tensorflow:global_step/sec: 8.40881
# INFO:tensorflow:step = 14500, loss = 0.07564258 (11.895 sec)
# INFO:tensorflow:global_step/sec: 8.4532
# INFO:tensorflow:step = 14600, loss = 0.045572083 (11.828 sec)
# INFO:tensorflow:global_step/sec: 8.43647
# INFO:tensorflow:step = 14700, loss = 0.020733628 (11.853 sec)
# INFO:tensorflow:global_step/sec: 8.30013
# INFO:tensorflow:step = 14800, loss = 0.05636331 (12.048 sec)
# INFO:tensorflow:global_step/sec: 8.68618
# INFO:tensorflow:step = 14900, loss = 0.021706067 (11.513 sec)
# INFO:tensorflow:global_step/sec: 8.4491
# INFO:tensorflow:step = 15000, loss = 0.05220009 (11.836 sec)
# INFO:tensorflow:global_step/sec: 8.41157
# INFO:tensorflow:step = 15100, loss = 0.028623397 (11.888 sec)
# INFO:tensorflow:global_step/sec: 8.51256
# INFO:tensorflow:step = 15200, loss = 0.04351263 (11.747 sec)
# INFO:tensorflow:Saving checkpoints for 15249 into /data/ts_cost_function/model_emb_rnn_rnn_features/model.ckpt.
# INFO:tensorflow:global_step/sec: 8.3455
# INFO:tensorflow:step = 15300, loss = 0.06468182 (11.983 sec)
# INFO:tensorflow:global_step/sec: 8.46379
# INFO:tensorflow:step = 15400, loss = 0.016870975 (11.815 sec)
# INFO:tensorflow:global_step/sec: 8.02939
# INFO:tensorflow:step = 15500, loss = 0.006200457 (12.454 sec)
# INFO:tensorflow:global_step/sec: 8.57954
# INFO:tensorflow:step = 15600, loss = 0.034871586 (11.656 sec)
# INFO:tensorflow:global_step/sec: 8.59076
# INFO:tensorflow:step = 15700, loss = 0.011307619 (11.640 sec)
# INFO:tensorflow:global_step/sec: 8.27873
# INFO:tensorflow:step = 15800, loss = 0.06938597 (12.080 sec)
# INFO:tensorflow:global_step/sec: 8.61591
# INFO:tensorflow:step = 15900, loss = 0.019286646 (11.606 sec)
# INFO:tensorflow:global_step/sec: 8.35128
# INFO:tensorflow:step = 16000, loss = 0.23360129 (11.974 sec)
# INFO:tensorflow:global_step/sec: 8.46973
# INFO:tensorflow:step = 16100, loss = 0.02515454 (11.807 sec)
# INFO:tensorflow:global_step/sec: 8.42026
# INFO:tensorflow:step = 16200, loss = 0.016748754 (11.877 sec)
# INFO:tensorflow:global_step/sec: 8.41068
# INFO:tensorflow:step = 16300, loss = 0.019618899 (11.889 sec)
# INFO:tensorflow:global_step/sec: 8.2264
# INFO:tensorflow:step = 16400, loss = 0.020321298 (12.156 sec)
# INFO:tensorflow:global_step/sec: 8.55428
# INFO:tensorflow:step = 16500, loss = 0.07025272 (11.690 sec)
# INFO:tensorflow:global_step/sec: 8.65158
# INFO:tensorflow:step = 16600, loss = 0.04382061 (11.558 sec)
# INFO:tensorflow:global_step/sec: 8.49453
# INFO:tensorflow:step = 16700, loss = 0.06138525 (11.773 sec)
# INFO:tensorflow:global_step/sec: 9.43798
# INFO:tensorflow:step = 16800, loss = 0.036967356 (10.595 sec)
# INFO:tensorflow:global_step/sec: 9.07597
# INFO:tensorflow:step = 16900, loss = 0.067114316 (11.018 sec)
# INFO:tensorflow:Saving checkpoints for 17000 into /data/ts_cost_function/model_emb_rnn_rnn_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.014681567.

# %% [markdown]
# ### Predict

# %%
global_batch_size = 5

pred_generator = model_emb_rnn_rnn.predict(
    input_fn=lambda:eval_word_emb_fn(
        test_df,
        global_batch_size,
        model_emb_rnn_rnn),
    yield_single_examples=False)

preds = []
for i in range(800):
    outputs = next(pred_generator)
    preds.append((outputs["logits"],outputs["word_outputs"],outputs["sent_outputs"]))
pred_reg,word_outputs,sent_outputs = list(zip(*preds))
#pred_reg = np.concatenate(pred_reg)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7f5cf1f3bd68>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /data/ts_cost_function/model_emb_rnn_rnn_features/model.ckpt-17000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %% [markdown]
# #### MSE per Feature

# %%
pred_reg = np.reshape(pred_reg,(4000,20))

# %%
act = test_df.iloc[:4000][feature_columns].values
mse = [mean_squared_error(pred_reg[:,ind],act[:,ind]) for ind,feature in enumerate(feature_columns)]
fig = plt.figure(1, figsize=(15, 6))
plt.bar(feature_columns,mse)
plt.ylabel("MSE")
plt.xticks(feature_columns, rotation='vertical')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# The graph shows the MSE of predicted feature scores of 4000 test texts. The chart clearly shows that most of the feature scores can easilier be predicted. Nevertheless, the appearance of complements, appositions, passive verbs, parataxis and negations seems to be more difficult to predict. The highest error has the parataxis feature, which could ne explained by the fact that it is a syntactical feature, that can mostly only be identified comparing different sentences. The word LSTM can not identify it, while the sentence LSTM doesn't learn the pattern.
# </div>
